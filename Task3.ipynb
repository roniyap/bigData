# %%
import json
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def reduce_memory(df):
    for col in df.columns:
        if df[col].dtype == 'float64':
            df[col] = df[col].astype('float32')
        if df[col].dtype == 'int64':
            df[col] = df[col].astype('int32')
    return df

df_games = reduce_memory(pd.read_csv("games.csv", index_col = "app_id"))
df_games["date_release"] = df_games["date_release"].astype(str).str[:4].astype(int)
df_games.rename(columns={"date_release": "year_release"}, inplace=True)
df_games.head(5)
# Out:
#                                     title  year_release   win    mac  linux  \
# app_id
# 13500   Prince of Persia: Warrior Within™          2008  True  False  False
# 22364             BRINK: Agents of Change          2011  True  False  False
# 113020       Monaco: What's Yours Is Mine          2013  True   True   True
# 226560                 Escape Dead Island          2014  True  False  False
# 249050            Dungeon of the ENDLESS™          2014  True   True  False
#
#                rating  positive_ratio  user_reviews  price_final  \
# app_id
# 13500   Very Positive              84          2199         9.99
# 22364        Positive              85            21         2.99
# 113020  Very Positive              92          3722        14.99
# 226560          Mixed              61           873        14.99
# 249050  Very Positive              88          8784        11.99
#
#         price_original  discount  steam_deck
# app_id
# 13500             9.99       0.0        True
# 22364             2.99       0.0        True
# 113020           14.99       0.0        True
# 226560           14.99       0.0        True
# 249050           11.99       0.0        True

# %%
file_path = "recommendations.csv"

# Read in chunks
chunksize = 10000  # Adjust based on memory
chunks = []

for chunk in pd.read_csv(file_path, index_col="app_id", chunksize=chunksize):
    chunk = reduce_memory(chunk)  # Apply memory reduction
    chunks.append(chunk)

# Combine all chunks into a single DataFrame
df_recs = pd.concat(chunks, ignore_index=False)

# Print result
df_recs.head()
# Out:
#          helpful  funny        date  is_recommended       hours  user_id  \
# app_id
# 975370         0      0  2022-12-12            True   36.299999    51580
# 304390         4      0  2017-02-17           False   11.500000     2586
# 1085660        2      0  2019-11-17            True  336.500000   253880
# 703080         0      0  2022-09-23            True   27.400000   259432
# 526870         0      0  2021-01-10            True    7.900000    23869
#
#          review_id
# app_id
# 975370           0
# 304390           1
# 1085660          2
# 703080           3
# 526870           4

# %%
df_users = reduce_memory(pd.read_csv("users.csv", index_col = "user_id"))
df_users.head(5)
# Out:
#           products  reviews
# user_id
# 7360263        359        0
# 14020781       156        1
# 8762579        329        4
# 4820647        176        4
# 5167327         98        2

# %%
meta_data = reduce_memory(pd.read_json("games_metadata.json"))
meta_data["tags"] = meta_data["tags"].apply(lambda x: ", ".join(x) if isinstance(x, list) else x)

meta_data.head(5)
# Out:
#    app_id                                        description  \
# 0   13500  Enter the dark underworld of Prince of Persia ...
# 1   22364
# 2  113020  Monaco: What's Yours Is Mine is a single playe...
# 3  226560  Escape Dead Island is a Survival-Mystery adven...
# 4  249050  Dungeon of the Endless is a Rogue-Like Dungeon...
#
#                                                 tags
# 0  Action, Adventure, Parkour, Third Person, Grea...
# 1                                             Action
# 2  Co-op, Stealth, Indie, Heist, Local Co-Op, Str...
# 3  Zombies, Adventure, Survival, Action, Third Pe...
# 4  Roguelike, Strategy, Tower Defense, Pixel Grap...

# %% [markdown]
# For analysing pricing trends we can find the average price of games by year of release:

# %%
avg_price = df_games.groupby("year_release")["price_final"].agg("mean")
print(avg_price)
# Out:
# year_release
# 1997     4.995000
# 1998     9.990000
# 1999     3.326667
# 2000     7.490000
# 2001     4.990000
# 2002     4.940000
# 2003     5.990000
# 2004     8.740000
# 2005     1.160000
# 2006     6.901786
# 2007     7.463658
# 2008     8.967465
# 2009     9.501024
# 2010     8.366302
# 2011     8.433165
# 2012     9.510566
# 2013     9.757214
# 2014     9.033061
# 2015     7.833925
# 2016     7.571791
# 2017     7.676552
# 2018     7.615424
# 2019     8.339868
# 2020     8.459524
# 2021     8.439894
# 2022     9.917744
# 2023    11.239883
# Name: price_final, dtype: float32

# %% [markdown]
# Find the most common genres in the dataset to see which genres are trending

# %%
genres = []
genre_count = {}
#Many genres are listed per entry
#Split and count the occurences of each genre avoiding duplicates
for g in meta_data["tags"]:
    if pd.isna(g) or g.strip() == "":  
        continue
    for genre in g.split(","):
        genre = genre.strip()
        if genre not in genres:
            genres.append(genre)
            genre_count[genre] = 0
        
        genre_count[genre] +=1

sorted_genre_count = dict(sorted(genre_count.items(), key=lambda item: item[1], reverse=True))

for genre, count in sorted_genre_count.items():
    print(f"{genre}: {count}")
# Out:
# Indie: 27957
# Singleplayer: 22566
# Action: 21897
# Adventure: 20183
# Casual: 17844
# Simulation: 12691
# 2D: 11438
# Strategy: 11093
# RPG: 10156
# Atmospheric: 8688
# Puzzle: 7585
# Story Rich: 7149
# Multiplayer: 6575
# 3D: 6142
# Pixel Graphics: 6028
# Exploration: 5769
# Cute: 5702
# Colorful: 5693
# Free to Play: 5645
# First-Person: 5570
# Early Access: 5308
# Fantasy: 5174
# Anime: 5002
# Funny: 4956
# Horror: 4789
# Arcade: 4502
# Shooter: 4389
# Family Friendly: 4286
# Female Protagonist: 4222
# Retro: 4153
# Sci-fi: 4113
# Platformer: 3998
# Difficult: 3923
# Relaxing: 3922
# Great Soundtrack: 3912
# Violent: 3676
# Open World: 3603
# Action-Adventure: 3367
# Survival: 3265
# Visual Novel: 3241
# Co-op: 3214
# Gore: 3185
# Third Person: 3174
# Comedy: 3125
# VR: 3098
# FPS: 3044
# Psychological Horror: 2879
# Stylized: 2874
# Realistic: 2838
# Point & Click: 2773
# Controller: 2758
# Sandbox: 2739
# Mystery: 2737
# Choices Matter: 2641
# Top-Down: 2603
# Dark: 2570
# Sports: 2542
# PvP: 2538
# Physics: 2519
# Combat: 2387
# Multiple Endings: 2357
# Minimalist: 2322
# Sexual Content: 2294
# Nudity: 2272
# Management: 2254
# Cartoony: 2245
# Building: 2150
# Racing: 2100
# 2D Platformer: 2096
# Side Scroller: 2085
# Linear: 2048
# Tactical: 2037
# Space: 2022
# Roguelike: 2012
# Character Customization: 1989
# Hand-drawn: 1860
# Turn-Based Strategy: 1841
# Action RPG: 1821
# Roguelite: 1804
# Massively Multiplayer: 1779
# Online Co-Op: 1771
# Puzzle Platformer: 1736
# Local Multiplayer: 1728
# Replay Value: 1662
# Survival Horror: 1645
# Magic: 1638
# Turn-Based: 1596
# Hidden Object: 1594
# Old School: 1591
# Crafting: 1590
# Logic: 1576
# Turn-Based Combat: 1568
# Historical: 1557
# Procedural Generation: 1552
# PvE: 1530
# Interactive Fiction: 1521
# Drama: 1520
# Choose Your Own Adventure: 1508
# Walking Simulator: 1498
# JRPG: 1491
# Shoot 'Em Up: 1471
# Turn-Based Tactics: 1465
# Hack and Slash: 1449
# Medieval: 1428
# 3D Platformer: 1419
# Futuristic: 1418
# Local Co-Op: 1399
# Zombies: 1387
# Resource Management: 1385
# War: 1358
# Cartoon: 1357
# Short: 1349
# Dungeon Crawler: 1324
# Bullet Hell: 1322
# Classic: 1316
# Surreal: 1306
# Emotional: 1292
# Romance: 1278
# Isometric: 1263
# Conspiracy: 250
# Cooking: 248
# Auto Battler: 245
# Ninja: 244
# Hunting: 242
# Dinosaurs: 241
# Dog: 241
# Programming: 237
# Hacking: 234
# Political Sim: 229
# Naval: 224
# Underwater: 222
# Vampire: 222
# Escape Room: 221
# Western: 220
# Politics: 219
# Underground: 216
# Faith: 215
# Touch-Friendly: 214
# Narrative: 212
# Mining: 209
# Fishing: 206
# Dynamic Narration: 206
# Illuminati: 199
# Quick-Time Events: 197
# Cold War: 195
# Immersive: 190
# Video Production: 189
# Asynchronous Multiplayer: 188
# Party Game: 187
# MOBA: 178
# Minigames: 174
# Looter Shooter: 174
# Transportation: 173
# Superhero: 172
# Villain Protagonist: 170
# Assassin: 167
# Kickstarter: 166
# Roguelike Deckbuilder: 165
# Time Attack: 160
# Typing: 160
# Web Publishing: 156
# Experience: 155
# Heist: 154
# Sequel: 152
# Naval Combat: 151
# Traditional Roguelike: 150
# Episodic: 148
# Party: 148
# Diplomacy: 148
# Nostalgia: 144
# Mod: 144
# Sailing: 143
# GameMaker: 142
# On-Rails Shooter: 142
# Cozy: 142
# Wholesome: 141
# Action RTS: 140
# Audio Production: 139
# Software Training: 139
# Snow: 134
# Trivia: 134
# Football (Soccer): 133
# Offroad: 131
# TrackIR: 126
# Chess: 121
# Sniper: 120
# Music-Based Procedural Generation: 120
# Archery: 120
# Mars: 119
# Horses: 117
# LEGO: 116
# World War I: 113
# Motorbike: 101
# Epic: 100
# Rome: 100
# Movie: 98
# Photo Editing: 96
# Gambling: 96
# Foreign: 95
# Unforgiving: 95
# Werewolves: 94
# Crowdfunded: 93
# Farming: 91
# Medical Sim: 89
# Silent Protagonist: 89
# Bikes: 86
# Boxing: 85
# Pinball: 85
# Golf: 82
# Social Deduction: 82
# Transhumanism: 81
# Spelling: 78
# Outbreak Sim: 75
# Games Workshop: 72
# Based On A Novel: 70
# Submarine: 68
# Dungeons & Dragons: 66
# Warhammer 40K: 66
# Spaceships: 64
# Roguevania: 64
# Football (American): 63
# Vikings: 62
# Basketball: 60
# Jet: 60
# Ambient: 57
# Electronic Music: 57
# 360 Video: 56
# Asymmetric VR: 52
# Documentary: 49
# Mini Golf: 47
# Gaming: 46
# Wrestling: 45
# Motocross: 45
# Intentionally Awkward Controls: 45
# Skateboarding: 43
# Pool: 41
# Cycling: 40
# Tennis: 39
# Baseball: 37
# Lemmings: 37
# Skating: 36
# Jump Scare: 32
# Instrumental Music: 29
# Snowboarding: 29
# Job Simulator: 28
# Mahjong: 27
# Electronic: 26
# Skiing: 25
# Hockey: 25
# Musou: 24
# Benchmark: 24
# Rock Music: 23
# Well-Written: 22
# Boss Rush: 22
# 8-bit Music: 21
# ATV: 20
# Voice Control: 20
# Bowling: 20
# Cricket: 20
# BMX: 18
# Rugby: 16
# Hardware: 14
# Reboot: 12
# Feature Film: 12
# Snooker: 11
# Steam Machine: 11
# Shop Keeper: 10
# Volleyball: 10
# Hobby Sim: 6
# Tile-Matching: 5
# Fox: 5
# Coding: 4

# %% [markdown]
# We could identify which price points generate the most recommendations:

# %%
df_merged = df_games.merge(df_recs, on="app_id", how="inner")
df_price_recommendations =df_merged[df_merged["is_recommended"] == True].groupby("price_final")["app_id"].count().reset_index().rename(columns={"app_id": "num_recommendations"})

df_price_recommendations = df_price_recommendations.sort_values(by="num_recommendations", ascending=False)

# Display results
print(df_price_recommendations.head())
